# %% [markdown]
# # LemGendary Training: LemGendizedFaceDataset -> yolov8n_face
# This notebook executes the exact LemGendary Neural Architecture Training natively on Kaggle T4/P100 hardware.

# %%
# !git clone https://github.com/lemgenda/lemgendary-training-suite.git
# %cd lemgendary-training-suite
# !pip install -r requirements.txt

# %%
# Run this cell to spawn the isolated training loop using Kaggle's internal mounted pathing directly.
# !python training/train.py --model yolov8n_face --env kaggle
