# %% [markdown]
# # LemGendary Multi-Mount Execution: Global_Detection_and_Face
# This notebook natively executes the explicit LemGendary Neural Architecture topologies directly upon T4/P100 hardware.

# %%
# !git clone https://github.com/lemgenda/lemgendary-training-suite.git
# %cd lemgendary-training-suite
# !pip install -r requirements.txt

# %%
# EXPLICIT CLOUD METADATA REQUIREMENT:
# Ensure ALL 2 datasets below are physically mounted via Kaggle 'Add Data':
# -> LemGendizedDetectionDataset
# -> LemGendizedFaceDataset

# !python training/train.py --model retinaface_mobilenet --env kaggle
# !python training/train.py --model retinaface_resnet --env kaggle
# !python training/train.py --model yolov8n --env kaggle
