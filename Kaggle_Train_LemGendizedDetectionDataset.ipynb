# %% [markdown]
# # LemGendary Training: LemGendizedDetectionDataset Clustered Execution
# This notebook executes all associated LemGendary Neural Architecture Models for this specific dataset natively on Kaggle T4/P100 hardware.

# %%
# !git clone https://github.com/lemgenda/lemgendary-training-suite.git
# %cd lemgendary-training-suite
# !pip install -r requirements.txt

# %%
# Run this cell to spawn the isolated training loops using Kaggle's internal mounted pathing directly.
# !python training/train.py --model retinaface_mobilenet --env kaggle
# !python training/train.py --model retinaface_resnet --env kaggle
# !python training/train.py --model yolov8n --env kaggle
